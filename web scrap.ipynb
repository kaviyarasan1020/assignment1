# %% [markdown]
# # assignment 1

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=redmi%20mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
respones=requests.get(url)

# %%
respones
# Out:
# <Response [200]>

# %%
redmi=BeautifulSoup(respones.text)

# %%
redmi
# Out:
# <!DOCTYPE html>
# ...

# %%
mobilename=redmi.select("._4rR01T")

# %%
mobilename
# Out:
# [<div class="_4rR01T">REDMI 10 (Pacific Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Shadow Black, 64 GB)</div>,
#  <div class="_4rR01T">REDMI A1 (Black, 32 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Midnight Black, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Midnight Black, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Charcoal Black, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Sea Blue, 32 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Slate Grey, 32 GB)</div>,
#  <div class="_4rR01T">REDMI A1 (Light Green, 32 GB)</div>,
#  <div class="_4rR01T">REDMI A1 (Light Blue, 32 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Sunrise Orange, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 Power (Sporty Orange, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10 Power (Power Black, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Caribbean Green, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Slate grey, 64 GB)</div>,
# ...

# %%
mobilename_rating=redmi.select("._1lRcqv ._3LWZlK")

# %%
mobilename_rating
# Out:
# [<div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
# ...

# %%
mobilename_price=redmi.select("._1_WHN1")

# %%
mobilename_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,462</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,349</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,478</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,090</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,245</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,298</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,698</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹27,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,850</div>,
# ...

# %%
import pandas as pds

# %%
mobilename=pds.DataFrame({'mobiles':mobilename,'rating':mobilename_rating,'price':mobilename_price})

# %%
mobilename
# Out:
#                                              mobiles     rating      price
# 0                   [REDMI 10 (Pacific Blue, 64 GB)]  [4.3, []]   [₹9,999]
# 1                   [REDMI 10 (Shadow Black, 64 GB)]  [4.3, []]   [₹9,999]
# 2                          [REDMI A1 (Black, 32 GB)]  [4.2, []]   [₹6,462]
# 3                 [REDMI 10 (Midnight Black, 64 GB)]  [4.3, []]   [₹9,999]
# 4                [REDMI 10 (Midnight Black, 128 GB)]  [4.2, []]  [₹11,999]
# 5                [REDMI 10A (Charcoal Black, 64 GB)]  [4.2, []]   [₹8,349]
# 6                      [REDMI 10A (Sea Blue, 32 GB)]  [4.1, []]   [₹7,999]
# 7                    [REDMI 10A (Slate Grey, 32 GB)]  [4.1, []]   [₹7,499]
# 8                    [REDMI A1 (Light Green, 32 GB)]  [4.2, []]   [₹6,478]
# 9                     [REDMI A1 (Light Blue, 32 GB)]  [4.2, []]   [₹6,090]
# 10                [REDMI 10 (Sunrise Orange, 64 GB)]  [4.3, []]   [₹9,999]
# ...

# %%
d=mobilename.to_csv('C:/kavi/mob.csv')

# %%
file=pds.read_csv('C:/kavi/mob.csv')

# %%
file
# Out:
#     Unnamed: 0                                            mobiles  \
# 0            0  <div class="_4rR01T">REDMI 10 (Pacific Blue, 6...
# 1            1  <div class="_4rR01T">REDMI 10 (Shadow Black, 6...
# 2            2  <div class="_4rR01T">REDMI A1 (Black, 32 GB)</...
# 3            3  <div class="_4rR01T">REDMI 10 (Midnight Black,...
# 4            4  <div class="_4rR01T">REDMI 10 (Midnight Black,...
# 5            5  <div class="_4rR01T">REDMI 10A (Charcoal Black...
# 6            6  <div class="_4rR01T">REDMI 10A (Sea Blue, 32 G...
# 7            7  <div class="_4rR01T">REDMI 10A (Slate Grey, 32...
# 8            8  <div class="_4rR01T">REDMI A1 (Light Green, 32...
# 9            9  <div class="_4rR01T">REDMI A1 (Light Blue, 32 ...
# 10          10  <div class="_4rR01T">REDMI 10 (Sunrise Orange,...
# 11          11  <div class="_4rR01T">REDMI 10 Power (Sporty Or...
# 12          12  <div class="_4rR01T">REDMI 10 Power (Power Bla...
# ...

# %%
edit=file["mobiles"]

# %%
edit
# Out:
# 0     <div class="_4rR01T">REDMI 10 (Pacific Blue, 6...
# 1     <div class="_4rR01T">REDMI 10 (Shadow Black, 6...
# 2     <div class="_4rR01T">REDMI A1 (Black, 32 GB)</...
# 3     <div class="_4rR01T">REDMI 10 (Midnight Black,...
# 4     <div class="_4rR01T">REDMI 10 (Midnight Black,...
# 5     <div class="_4rR01T">REDMI 10A (Charcoal Black...
# 6     <div class="_4rR01T">REDMI 10A (Sea Blue, 32 G...
# 7     <div class="_4rR01T">REDMI 10A (Slate Grey, 32...
# 8     <div class="_4rR01T">REDMI A1 (Light Green, 32...
# 9     <div class="_4rR01T">REDMI A1 (Light Blue, 32 ...
# 10    <div class="_4rR01T">REDMI 10 (Sunrise Orange,...
# 11    <div class="_4rR01T">REDMI 10 Power (Sporty Or...
# 12    <div class="_4rR01T">REDMI 10 Power (Power Bla...
# 13    <div class="_4rR01T">REDMI 10 (Caribbean Green...
# 14    <div class="_4rR01T">REDMI 10A (Slate grey, 64...
# 15    <div class="_4rR01T">REDMI 10 (Caribbean Green...
# 16    <div class="_4rR01T">REDMI 10A (Sea Blue, 64 G...
# ...

# %%
edit=edit.str.strip('<div class="_4rR01T">').astype(str)

# %%
edit
# Out:
# 0                     EDMI 10 (Pacific Blue, 64 GB)</
# 1                     EDMI 10 (Shadow Black, 64 GB)</
# 2                            EDMI A1 (Black, 32 GB)</
# 3                   EDMI 10 (Midnight Black, 64 GB)</
# 4                  EDMI 10 (Midnight Black, 128 GB)</
# 5                  EDMI 10A (Charcoal Black, 64 GB)</
# 6                        EDMI 10A (Sea Blue, 32 GB)</
# 7                      EDMI 10A (Slate Grey, 32 GB)</
# 8                      EDMI A1 (Light Green, 32 GB)</
# 9                       EDMI A1 (Light Blue, 32 GB)</
# 10                  EDMI 10 (Sunrise Orange, 64 GB)</
# 11            EDMI 10 Power (Sporty Orange, 128 GB)</
# 12              EDMI 10 Power (Power Black, 128 GB)</
# 13                EDMI 10 (Caribbean Green, 128 GB)</
# 14                     EDMI 10A (Slate grey, 64 GB)</
# 15                 EDMI 10 (Caribbean Green, 64 GB)</
# 16                       EDMI 10A (Sea Blue, 64 GB)</
# ...
